# %%
#Matplotlib
#Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randint
# %matplotlib inline

# %% [markdown]
# # Simple chart with MatplotLib

# %%
x = np.linspace(1, 10, 20)
x
# Geberate 20 random numbers between 1,50

y = randint(1, 50, 20)
y
# Out:
# array([32, 41, 36,  6, 48, 16, 48, 13, 17, 42,  7, 32, 12, 42, 34, 36,  3,
#        18, 44, 45])

# %%
plt.plot(y)

# %%
#Adding Label
plt.plot(x, y, color = 'g')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Random Plot')
plt.show()

# %% [markdown]
# #Scatter, Bar, Hist, and Box Plots
# plt.scatter(x, y)

# %% [markdown]
# # viszvalization using Pandas
# #pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, in Python programming #language. It is a high-level data manipulation tool developed by Wes McKinney

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn, randint, uniform, sample

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ax = iris['sepal_length'].plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
y.plot(figsize = (16,10), secondary_y = True, ax = ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-37c6085a8f57> in <module>
#       1 ax = iris.plot(figsize=(15,8), title='Iris Dataset')
# ----> 2 y.plot(figsize = (16,10), secondary_y = True, ax = ax)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
# Histogram
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'box', figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind = 'box', figsize=(10,5),  vert = False)
# Out:
# <AxesSubplot:>

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
#c is a parameter which decides the color of each point. 
#Here we have passed the column name sepal_width whose values will be used to color the marker points according to a colormap.
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(iris, figsize= (8,8), diagonal='kde', color = 'r')
plt.show()

# %%
import seaborn
# Pairplot using Seabron
seaborn.pairplot(iris)
plt.show()

# %%
iris.plot(subplots = True, sharex = False)
plt.tight_layout()

# %%
import seaborn
correlations = iris.corr()
seaborn.heatmap(correlations)
plt.show()

# %%
# Load the Tips data for advanced viszvilations
tips = sns.load_dataset('tips')
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.set(style = 'darkgrid')

# %%
# Simple relation plot between  bill and Tip
sns.relplot(x = 'total_bill', y = 'tip', data = tips)

# %%
# Adding categories in the Map
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', style = 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip', style = 'size', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, size = 'size', sizes = (15, 200))

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips)

# %% [markdown]
# # 2. Categorical Data Ploting

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['sex'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.pie(tips['smoker'].value_counts(),labels=['yes','no'],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e0a85e0>,
# ...
#  [Text(-0.4012471747910624, 1.0242073543585746, 'yes'),
#   Text(0.4012470788978477, -1.024207391926042, 'no')])

# %%
sns.countplot(x='sex', hue='smoker', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.catplot(x = 'sex', y = 'smoker', hue = 'class', kind = 'bar', data = titanic)

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex')

# %%
sns.catplot(x = 'total_bill', y = 'day', hue = 'sex', kind = 'violin', data = tips, split = True,)

# %%
#The Violin plot is very much similar to a box plot, 
#with the addition of a rotated kernel density plot on each side. 
#It shows the distribution of quantitative data across several levels of one (or more) 
#categorical variables such that those distributions can be compared.

g = sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', inner = None, data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', color = 'k', size = 3, data = tips, ax = g.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
